# %% [markdown]
# #<font color=green size=10>Bibliotecas utilizadas</font>

# %%
import pandas as pd

# %% [markdown]
# #<font color=green size=10>Extração do arquivo tratado no projeto anterior</font>

# %%
df = pd.read_csv('/content/dados_telecom_x.csv')
df
# Out:
#       Id cliente Desistente    Sexo  Idade 65+ Casado Filhos  \
# 0     0002-ORFBO         No  Female          0    Yes    Yes
# 1     0003-MKNFE         No    Male          0     No     No
# 2     0004-TLHLJ        Yes    Male          0     No     No
# 3     0011-IGKFF        Yes    Male          1    Yes     No
# 4     0013-EXCHZ        Yes  Female          1    Yes     No
# ...          ...        ...     ...        ...    ...    ...
# 7038  9987-LUTYD         No  Female          0     No     No
# 7039  9992-RRAMN        Yes    Male          0    Yes     No
# 7040  9992-UJOEL         No    Male          0     No     No
# 7041  9993-LHIEB         No    Male          0    Yes    Yes
# 7042  9995-HOTOH         No    Male          0    Yes    Yes
#
#       Há quanto tempo é cliente (meses) Serviço de telefone  \
# 0                                     9                 Yes
# 1                                     9                 Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Id cliente                         7043 non-null   object
#  1   Desistente                         7043 non-null   object
#  2   Sexo                               7043 non-null   object
#  3   Idade 65+                          7043 non-null   int64
#  4   Casado                             7043 non-null   object
#  5   Filhos                             7043 non-null   object
#  6   Há quanto tempo é cliente (meses)  7043 non-null   int64
#  7   Serviço de telefone                7043 non-null   object
#  8   Contratou mais de uma linha        7043 non-null   object
#  9   Serviço de internet                7043 non-null   object
#  10  Segurança online                   7043 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Id cliente                            0
# Desistente                            0
# Sexo                                  0
# Idade 65+                             0
# Casado                                0
# Filhos                                0
# Há quanto tempo é cliente (meses)     0
# Serviço de telefone                   0
# Contratou mais de uma linha           0
# Serviço de internet                   0
# Segurança online                      0
# Backup online                         0
# Proteção do dispositivo               0
# Suporte técnico                       0
# TV streaming                          0
# Streaming de Filmes                   0
# Duração do contrato                   0
# Fatura digital                        0
# Forma de pagamento                    0
# Valor diário                         11
# Valor mensal                          0
# Faturamento total                    11
# dtype: int64

# %% [markdown]
# #<font color=green size=10>Preparação dos dados</font>

# %%
df.columns
# Out:
# Index(['Id cliente', 'Desistente', 'Sexo', 'Idade 65+', 'Casado', 'Filhos',
#        'Há quanto tempo é cliente (meses)', 'Serviço de telefone',
#        'Contratou mais de uma linha', 'Serviço de internet',
#        'Segurança online', 'Backup online', 'Proteção do dispositivo',
#        'Suporte técnico', 'TV streaming', 'Streaming de Filmes',
#        'Duração do contrato', 'Fatura digital', 'Forma de pagamento',
#        'Valor diário', 'Valor mensal', 'Faturamento total'],
#       dtype='object')

# %%
del df['Id cliente']

# %%
df
# Out:
#      Desistente    Sexo  Idade 65+ Casado Filhos  \
# 0            No  Female          0    Yes    Yes
# 1            No    Male          0     No     No
# 2           Yes    Male          0     No     No
# 3           Yes    Male          1    Yes     No
# 4           Yes  Female          1    Yes     No
# ...         ...     ...        ...    ...    ...
# 7038         No  Female          0     No     No
# 7039        Yes    Male          0    Yes     No
# 7040         No    Male          0     No     No
# 7041         No    Male          0    Yes    Yes
# 7042         No    Male          0    Yes    Yes
#
#       Há quanto tempo é cliente (meses) Serviço de telefone  \
# 0                                     9                 Yes
# 1                                     9                 Yes
# 2                                     4                 Yes
# 3                                    13                 Yes
# 4                                     3                 Yes
# ...

# %%
df.columns
# Out:
# Index(['Desistente', 'Sexo', 'Idade 65+', 'Casado', 'Filhos',
#        'Há quanto tempo é cliente (meses)', 'Serviço de telefone',
#        'Contratou mais de uma linha', 'Serviço de internet',
#        'Segurança online', 'Backup online', 'Proteção do dispositivo',
#        'Suporte técnico', 'TV streaming', 'Streaming de Filmes',
#        'Duração do contrato', 'Fatura digital', 'Forma de pagamento',
#        'Valor diário', 'Valor mensal', 'Faturamento total'],
#       dtype='object')

# %% [markdown]
# <font color=green size=10>Encoding</font>

# %%
colunas_categoricas = df.select_dtypes(include='object').columns
print(colunas_categoricas)
# Out:
# Index(['Desistente', 'Sexo', 'Casado', 'Filhos', 'Serviço de telefone',
#        'Contratou mais de uma linha', 'Serviço de internet',
#        'Segurança online', 'Backup online', 'Proteção do dispositivo',
#        'Suporte técnico', 'TV streaming', 'Streaming de Filmes',
#        'Duração do contrato', 'Fatura digital', 'Forma de pagamento'],
#       dtype='object')

# %%
df = pd.get_dummies(df, columns=colunas_categoricas, drop_first=True)
df
# Out:
#       Idade 65+  Há quanto tempo é cliente (meses)  Valor diário  \
# 0             0                                  9          2.20
# 1             0                                  9          2.01
# 2             0                                  4          2.34
# 3             1                                 13          3.17
# 4             1                                  3          2.97
# ...         ...                                ...           ...
# 7038          0                                 13          1.90
# 7039          0                                 22          2.84
# 7040          0                                  2          1.55
# 7041          0                                 67          2.30
# 7042          0                                 63          1.96
#
#       Valor mensal  Faturamento total  Desistente_Yes  Sexo_Male  Casado_Yes  \
# 0            65.60             593.30           False      False        True
# ...

# %%
df['Desistente_Yes'].value_counts(normalize=True)
# Out:
# Desistente_Yes
# False    0.73463
# True     0.26537
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer

# %%
x = df.drop('Desistente_Yes', axis=1)
y = df['Desistente_Yes']

imputer = SimpleImputer(strategy='mean')
x_imputed = imputer.fit_transform(x)

smote = SMOTE(random_state=42)
x_res, y_res = smote.fit_resample(x_imputed, y)
